# %% [markdown]
# # show_tables_example
#
# In this tutorial we are going to use `show_tables` to explore databases, tables, and columns stored in S3.

# %%
import pandas as pd
import awswrangler as wr
import datetime
import pydbtools as pydb

# %%
#delete
import importlib
importlib.reload(pydb)
# Out:
# <module 'pydbtools' from '/Users/gustav.moller/Documents/pydbtools/pydbtools/__init__.py'>

# %% [markdown]
# The `show_tables()` function calls the following aws wrangler function which has the following paramaters.
#
# Parameters:
# - limit (int, optional) – Max number of tables to be returned. If none is provided, the default value is 100.
# - catalog_id (str, optional) – The ID of the Data Catalog from which to retrieve Databases. If none is provided, the AWS account ID is used by default.
# - database (str, optional) – Database name.
# - transaction_id (str, optional) – The ID of the transaction (i.e. used with GOVERNED tables).
# - search_text (str, optional) – Select only tables with the given string in table’s properties.
# - name_contains (str, optional) – Select by a specific string on table name
# - name_prefix (str, optional) – Select by a specific prefix on table name
# - name_suffix (str, optional) – Select by a specific suffix on table name
# - boto3_session (boto3.Session(), optional) – Boto3 Session. The default boto3 session will be used if boto3_session receive None.
#
# Returns:
# Pandas Dataframe filled by formatted infos.
#
# https://aws-sdk-pandas.readthedocs.io/en/stable/stubs/awswrangler.catalog.tables.html

# %% [markdown]
# If called on it's own, `show_tables()` will return the top 100 tables as a dataframe without any filters.

# %%
pydb.show_tables()
# Out:
#                            Database                 Table  \
# 0    accom_and_employ_qa_monitoring           sl014_table
# 1    accom_and_employ_qa_monitoring           sl016_table
# 2    accom_and_employ_qa_monitoring        test_remmc1020
# 3                 address_base_test     address_base_json
# 4                 address_base_test  address_base_parquet
# ..                              ...                   ...
# 995                       cases_raw             judgments
# 996                       cases_raw               parties
# 997                       cases_raw       warrant_returns
# 998                       cases_raw              warrants
# 999                          cbtest    inc_response_flags
#
#               Description       TableType  \
# 0                          EXTERNAL_TABLE
# 1                          EXTERNAL_TABLE
# 2                          EXTERNAL_TABLE
# 3                          EXTERNAL_TABLE
# 4                          EXTERNAL_TABLE
# ..                    ...             ...
# 995        judgments data  EXTERNAL_TABLE
# 996          parties data  EXTERNAL_TABLE
# 997  warrant_returns data  EXTERNAL_TABLE
# 998         warrants data  EXTERNAL_TABLE
# 999                        EXTERNAL_TABLE
#
#                                                Columns      Partitions
# 0    period, prison_nomis, prison_nd, nps_or_crc, n...
# 1    period, prison_nomis, prison_nd, nps_or_crc, n...
# 2                                          month, year
# 3    changetype, startdate, lastupdatedate, entryda...  snapshot, tile
# 4    changetype, startdate, lastupdatedate, entryda...  snapshot, tile
# ..                                                 ...             ...
# 995  judg_seq, judgment_type, joint_judgment, judgm...
# 996  party_id, person_title, person_given_first_nam...
# 997  warrant_returns_id, warrant_return_date, error...
# 998  warrant_id, local_warrant_number, warrant_numb...
# 999  questionnaire_ans_id, incident_type, questionn...
#
# [1000 rows x 6 columns]

# %% [markdown]
# Most of the time, we are interested in the tables of a specific database. This can be specified using the database argument. If the database has a large number of tables, the limit will also need to be adjusted.

# %%
pydb.show_tables(database="alpha_ccs_temp", limit=200)
# Out:
#            Database                                  Table Description  \
# 0    alpha_ccs_temp                 ccs_disposals_receipts
# 1    alpha_ccs_temp     ccs_disposals_receipts_post_sept21
# 2    alpha_ccs_temp      ccs_disposals_receipts_pre_sept21
# 3    alpha_ccs_temp          ccs_disposals_receipts_sdp_v2
# 4    alpha_ccs_temp          ccs_disposals_receipts_sdp_v3
# ..              ...                                    ...         ...
# 99   alpha_ccs_temp           opt_sitting_days_septemberv4
# 100  alpha_ccs_temp                         os_definitions
# 101  alpha_ccs_temp                                   test
# 102  alpha_ccs_temp  test_sdp_v1_mags_sjp_time_cp_20221020
# 103  alpha_ccs_temp                             timeliness
#
#           TableType                                            Columns  \
# 0    EXTERNAL_TABLE  disposal_year, disposal_quarter, disposal_mont...
# 1    EXTERNAL_TABLE  disposal_year, disposal_quarter, disposal_mont...
# 2    EXTERNAL_TABLE  disposal_year, disposal_quarter, disposal_mont...
# 3    EXTERNAL_TABLE  disposal_year, disposal_quarter, disposal_mont...
# 4    EXTERNAL_TABLE  disposal_year, disposal_quarter, disposal_mont...
# ..              ...                                                ...
# 99   EXTERNAL_TABLE  crn_id, crn_name, lcjb_area_id, lcjb_area_name...
# 100  EXTERNAL_TABLE                               variable, definition
# 101  EXTERNAL_TABLE  defendant_on_case_id, case_id, year, quarter, ...
# 102  EXTERNAL_TABLE  sdp_v1_flag, case_id, defendant_id, offence_de...
# 103  EXTERNAL_TABLE  year, quarter, age, n, valid_n, valid_n_and_cc...
#
#     Partitions
# 0
# 1
# 2
# 3
# 4
# ..         ...
# 99
# 100
# 101
# 102
# 103
#
# [104 rows x 6 columns]
